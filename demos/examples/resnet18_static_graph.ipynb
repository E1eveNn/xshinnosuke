# %%
from xshinnosuke.layers import Dense, Flatten, Conv2D, MaxPooling2D, AvgPooling2D, BatchNormalization, Activation, Add, Input
from xshinnosuke.models import Model
import cupy as np

# %%
def identity_block(X, filters, stage, block, s):
    conv_name_base = "res" + str(stage) + block + "_branch"
    bn_name_base = "bn" + str(stage) + block + "_branch"

    F1, F2 = filters

    X_shortcut = X

    X = Conv2D(out_channels=F1, kernel_size=(3, 3), stride=(s, s), padding=1,
               name=conv_name_base + "2a")(X)
    X = BatchNormalization()(X)
    X = Activation("relu")(X)
    X = Conv2D(out_channels=F2, kernel_size=(3, 3), stride=(1, 1), padding=1,
               name=conv_name_base + "2b")(X)
    X = BatchNormalization()(X)
    X = Add()([X, X_shortcut])
    X = Activation("relu")(X)
    
    return X


def convolutional_block(X, filters, stage, block, s=2):
    conv_name_base = "res" + str(stage) + block + "_branch"
    bn_name_base = "bn" + str(stage) + block + "_branch"

    F1, F2 = filters

    X_shortcut = X

    X = Conv2D(out_channels=F1, kernel_size=(3, 3), stride=(s, s), padding=1,
               name=conv_name_base + "2b")(X)
    X = BatchNormalization()(X)
    X = Activation("relu")(X)
    X = Conv2D(out_channels=F2, kernel_size=(3, 3), stride=(1, 1), padding=1,
               name=conv_name_base + "2c")(X)
    X = BatchNormalization()(X)


    X_shortcut = Conv2D(out_channels=F2, kernel_size=(1, 1), stride=(s, s),
                        name=conv_name_base + "1")(X_shortcut)
    X_shortcut = BatchNormalization()(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation("relu")(X)

    return X


def ResNet18(input_shape=(3, 56, 56), classes=100):
    X_input = Input(input_shape)

    # stage1
    X = Conv2D(out_channels=64, kernel_size=(7, 7), stride=(2, 2), name="conv1", padding=3)(X_input)
    X = BatchNormalization(name="bn1")(X)
    X = Activation("relu")(X)
    X = MaxPooling2D(kernel_size=3, stride=2, padding=1)(X)

    # stage2
    X = identity_block(X, filters=[64, 64], stage=2, block="b", s=1)
    X = identity_block(X, filters=[64, 64], stage=2, block="c", s=1)

    # stage3
    X = convolutional_block(X, filters=[128, 128], stage=3, block="a", s=2)
    X = identity_block(X, filters=[128, 128], stage=3, block="b", s=1)


    # stage4
    X = convolutional_block(X, filters=[256, 256], stage=4, block="a", s=2)
    X = identity_block(X, filters=[256, 256], stage=4, block="b", s=1)

    # stage5
    X = convolutional_block(X, filters=[512, 512], stage=5, block="a", s=2)
    X = identity_block(X, filters=[512, 512], stage=5, block="b", s=1)

    X = AvgPooling2D(2)(X)

    X = Flatten()(X)
    X = Dense(classes, name="fc" + str(classes),)(X)

    model = Model(inputs=X_input, outputs=X)

    return model

# %%
# random generate data
x = np.random.rand(500, 3, 56, 56)
y = np.random.randint(0, 100, (500,))

# %%
net = ResNet18()
net.compile(optimizer='sgd', loss='cross_entropy')
print(net)
# Out:
# ********************************************************************************
# Layer(type)                    Output Shape         Param      Connected to
# ################################################################################
# input0 (Input)                 (None, 3, 56, 56)    0
#
# --------------------------------------------------------------------------------
# conv1 (Conv2D)                 (None, 64, 28, 28)   9408       input0
# --------------------------------------------------------------------------------
# bn1 (BatchNormalization)       (None, 64, 28, 28)   128        conv1
# --------------------------------------------------------------------------------
# activation0 (Activation)       (None, 64, 28, 28)   0          bn1
# --------------------------------------------------------------------------------
# maxpooling2d0 (MaxPooling2D)   (None, 64, 14, 14)   0          activation0
# --------------------------------------------------------------------------------
# res2b_branch2a (Conv2D)        (None, 64, 14, 14)   36864      maxpooling2d0
# --------------------------------------------------------------------------------
# bn0 (BatchNormalization)       (None, 64, 14, 14)   128        res2b_branch2a
# --------------------------------------------------------------------------------
# activation1 (Activation)       (None, 64, 14, 14)   0          bn0
# --------------------------------------------------------------------------------
# res2b_branch2b (Conv2D)        (None, 64, 14, 14)   36864      activation1
# --------------------------------------------------------------------------------
# bn1 (BatchNormalization)       (None, 64, 14, 14)   128        res2b_branch2b
# --------------------------------------------------------------------------------
# add0 (Add)                     (None, 64, 14, 14)   0          bn1
#                                                                maxpooling2d0
# --------------------------------------------------------------------------------
# activation2 (Activation)       (None, 64, 14, 14)   0          add0
# --------------------------------------------------------------------------------
# res2c_branch2a (Conv2D)        (None, 64, 14, 14)   36864      activation2
# --------------------------------------------------------------------------------
# bn2 (BatchNormalization)       (None, 64, 14, 14)   128        res2c_branch2a
# --------------------------------------------------------------------------------
# activation3 (Activation)       (None, 64, 14, 14)   0          bn2
# --------------------------------------------------------------------------------
# res2c_branch2b (Conv2D)        (None, 64, 14, 14)   36864      activation3
# --------------------------------------------------------------------------------
# bn3 (BatchNormalization)       (None, 64, 14, 14)   128        res2c_branch2b
# --------------------------------------------------------------------------------
# add1 (Add)                     (None, 64, 14, 14)   0          bn3
#                                                                activation2
# --------------------------------------------------------------------------------
# activation4 (Activation)       (None, 64, 14, 14)   0          add1
# --------------------------------------------------------------------------------
# res3a_branch1 (Conv2D)         (None, 128, 7, 7)    8192       activation4
# --------------------------------------------------------------------------------
# res3a_branch2b (Conv2D)        (None, 128, 7, 7)    73728      activation4
# --------------------------------------------------------------------------------
# bn4 (BatchNormalization)       (None, 128, 7, 7)    256        res3a_branch1
# --------------------------------------------------------------------------------
# bn5 (BatchNormalization)       (None, 128, 7, 7)    256        res3a_branch2b
# --------------------------------------------------------------------------------
# activation5 (Activation)       (None, 128, 7, 7)    0          bn5
# --------------------------------------------------------------------------------
# res3a_branch2c (Conv2D)        (None, 128, 7, 7)    147456     activation5
# --------------------------------------------------------------------------------
# bn6 (BatchNormalization)       (None, 128, 7, 7)    256        res3a_branch2c
# --------------------------------------------------------------------------------
# add2 (Add)                     (None, 128, 7, 7)    0          bn6
#                                                                bn4
# --------------------------------------------------------------------------------
# activation6 (Activation)       (None, 128, 7, 7)    0          add2
# --------------------------------------------------------------------------------
# res3b_branch2a (Conv2D)        (None, 128, 7, 7)    147456     activation6
# --------------------------------------------------------------------------------
# bn7 (BatchNormalization)       (None, 128, 7, 7)    256        res3b_branch2a
# --------------------------------------------------------------------------------
# activation7 (Activation)       (None, 128, 7, 7)    0          bn7
# --------------------------------------------------------------------------------
# res3b_branch2b (Conv2D)        (None, 128, 7, 7)    147456     activation7
# --------------------------------------------------------------------------------
# bn8 (BatchNormalization)       (None, 128, 7, 7)    256        res3b_branch2b
# --------------------------------------------------------------------------------
# add3 (Add)                     (None, 128, 7, 7)    0          bn8
#                                                                activation6
# --------------------------------------------------------------------------------
# activation8 (Activation)       (None, 128, 7, 7)    0          add3
# --------------------------------------------------------------------------------
# res4a_branch1 (Conv2D)         (None, 256, 4, 4)    32768      activation8
# --------------------------------------------------------------------------------
# bn9 (BatchNormalization)       (None, 256, 4, 4)    512        res4a_branch1
# --------------------------------------------------------------------------------
# res4a_branch2b (Conv2D)        (None, 256, 4, 4)    294912     activation8
# --------------------------------------------------------------------------------
# bn10 (BatchNormalization)      (None, 256, 4, 4)    512        res4a_branch2b
# --------------------------------------------------------------------------------
# activation9 (Activation)       (None, 256, 4, 4)    0          bn10
# --------------------------------------------------------------------------------
# res4a_branch2c (Conv2D)        (None, 256, 4, 4)    589824     activation9
# --------------------------------------------------------------------------------
# bn11 (BatchNormalization)      (None, 256, 4, 4)    512        res4a_branch2c
# --------------------------------------------------------------------------------
# add4 (Add)                     (None, 256, 4, 4)    0          bn11
#                                                                bn9
# --------------------------------------------------------------------------------
# activation10 (Activation)      (None, 256, 4, 4)    0          add4
# --------------------------------------------------------------------------------
# res4b_branch2a (Conv2D)        (None, 256, 4, 4)    589824     activation10
# --------------------------------------------------------------------------------
# bn12 (BatchNormalization)      (None, 256, 4, 4)    512        res4b_branch2a
# --------------------------------------------------------------------------------
# activation11 (Activation)      (None, 256, 4, 4)    0          bn12
# --------------------------------------------------------------------------------
# res4b_branch2b (Conv2D)        (None, 256, 4, 4)    589824     activation11
# --------------------------------------------------------------------------------
# bn13 (BatchNormalization)      (None, 256, 4, 4)    512        res4b_branch2b
# --------------------------------------------------------------------------------
# add5 (Add)                     (None, 256, 4, 4)    0          bn13
#                                                                activation10
# --------------------------------------------------------------------------------
# activation12 (Activation)      (None, 256, 4, 4)    0          add5
# --------------------------------------------------------------------------------
# res5a_branch2b (Conv2D)        (None, 512, 2, 2)    1179648    activation12
# --------------------------------------------------------------------------------
# bn14 (BatchNormalization)      (None, 512, 2, 2)    1024       res5a_branch2b
# --------------------------------------------------------------------------------
# res5a_branch1 (Conv2D)         (None, 512, 2, 2)    131072     activation12
# --------------------------------------------------------------------------------
# activation13 (Activation)      (None, 512, 2, 2)    0          bn14
# --------------------------------------------------------------------------------
# res5a_branch2c (Conv2D)        (None, 512, 2, 2)    2359296    activation13
# --------------------------------------------------------------------------------
# bn15 (BatchNormalization)      (None, 512, 2, 2)    1024       res5a_branch1
# --------------------------------------------------------------------------------
# bn16 (BatchNormalization)      (None, 512, 2, 2)    1024       res5a_branch2c
# --------------------------------------------------------------------------------
# add6 (Add)                     (None, 512, 2, 2)    0          bn16
#                                                                bn15
# --------------------------------------------------------------------------------
# activation14 (Activation)      (None, 512, 2, 2)    0          add6
# --------------------------------------------------------------------------------
# res5b_branch2a (Conv2D)        (None, 512, 2, 2)    2359296    activation14
# --------------------------------------------------------------------------------
# bn17 (BatchNormalization)      (None, 512, 2, 2)    1024       res5b_branch2a
# --------------------------------------------------------------------------------
# activation15 (Activation)      (None, 512, 2, 2)    0          bn17
# --------------------------------------------------------------------------------
# res5b_branch2b (Conv2D)        (None, 512, 2, 2)    2359296    activation15
# --------------------------------------------------------------------------------
# bn18 (BatchNormalization)      (None, 512, 2, 2)    1024       res5b_branch2b
# --------------------------------------------------------------------------------
# add7 (Add)                     (None, 512, 2, 2)    0          bn18
#                                                                activation14
# --------------------------------------------------------------------------------
# activation16 (Activation)      (None, 512, 2, 2)    0          add7
# --------------------------------------------------------------------------------
# avgpooling2d0 (AvgPooling2D)   (None, 512, 1, 1)    0          activation16
# --------------------------------------------------------------------------------
# flatten0 (Flatten)             (None, 512)          0          avgpooling2d0
# --------------------------------------------------------------------------------
# fc100 (Dense)                  (None, 100)          51300      flatten0
# --------------------------------------------------------------------------------
# ********************************************************************************
# Total params: 11227812
# Trainable params: 11227812
# Non-trainable params: 0

# %%
history = net.fit(x, y, batch_size=32, epochs=5)
# Out:
#  Epoch[1/5]
#  500/500 [===================>] - 12s - 761ms/batch -batch_loss: 5.5678 -batch_acc: 0.0000
#  Epoch[2/5]
#  500/500 [===================>] - 8s - 500ms/batch -batch_loss: 5.0011 -batch_acc: 0.050025
#  Epoch[3/5]
#  500/500 [===================>] - 7s - 458ms/batch -batch_loss: 2.7564 -batch_acc: 0.400000
#  Epoch[4/5]
#  500/500 [===================>] - 8s - 503ms/batch -batch_loss: 0.9067 -batch_acc: 0.900000
#  Epoch[5/5]
#  500/500 [===================>] - 8s - 487ms/batch -batch_loss: 0.0737 -batch_acc: 1.000000
